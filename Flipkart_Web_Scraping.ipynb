# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
# Function to extract Product Title
def get_title(soup):

    try:
        # Outer Tag Object
        title = soup.find("span", attrs={'class':'B_NuCI'})
        
        # Inner NavigatableString Object
        title_value = title.text

        # Title as a string value
        title_string = title_value.strip()

    except AttributeError:
        title_string = ""

    return title_string

# Function to extract Product Price
def get_price(soup):

    try:
        price = soup.find("div", attrs={'class':'_25b18c'}).find("div", attrs={'class':'_30jeq3 _16Jk6d'})
        price_value = price.text.strip()
        
    except:
        price_value = ""
        
    return price_value

# Function to extract Author
def get_author(author):
    try:
        author = new_soup.find("div", attrs={'class':'_2o-xpa'}).find("a", attrs={'class':'_1mXcCf RmoJUa _14Me7y'}).text
        author_name = author.strip()
        
    except AttributeError:
        author_name = ""
    return author_name

# %%
if __name__ == '__main__':

    # add your user agent 
    HEADERS = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36', 'Accept-Language': 'en-US, en;q=0.5'})

    # The webpage URL
    URL = "https://www.flipkart.com/search?q=books&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"

    # HTTP Request
    webpage = requests.get(URL, headers=HEADERS)

    # Soup Object containing all data
    soup = BeautifulSoup(webpage.content, "html.parser")

    # Fetch links as List of Tag Objects
    links = soup.find_all("a", attrs={'class':'_2rpwqI'})

    # Store the links
    links_list = []

    # Loop for extracting links from Tag Objects
    for link in links:
            links_list.append(link.get('href'))

    d = {"title":[], "price":[], "author":[]}
    
    # Loop for extracting product details from each link 
    for link in links_list:
        new_webpage = requests.get("https://www.flipkart.com" + link, headers=HEADERS)

        new_soup = BeautifulSoup(new_webpage.content, "html.parser")

        # Function calls to display all necessary product information
        d['title'].append(get_title(new_soup))
        d['price'].append(get_price(new_soup))
        d['author'].append(get_author(new_soup))

    
    flipkart_df = pd.DataFrame.from_dict(d)
    flipkart_df['title'].replace('', np.nan, inplace=True)
    flipkart_df = flipkart_df.dropna(subset=['title'])
    flipkart_df.to_csv("flipkart_data.csv", header=True, index=False)

# %%
flipkart_df
# Out:
#                                                 title   price  \
# 0   Talathi Bharti 2023: Sambhavy Sarav Prashnasan...    ₹291
# 1   Black Book Of English Vocabulary |Gupta Edutec...    ₹299
# 2   SSC General Studies 6500 TCS MCQ Chapter Wise ...    ₹499
# 3   SSC Reasoning 7200 TCS MCQ Chapter Wise 4th Ed...    ₹489
# 4   SSC English 7600 TCS MCQ Chapter Wise With Det...    ₹499
# 5   SSC MTS 2023 4800 TCS MCQ Chapter Wise With De...    ₹380
# 6   SSC General Studies 6500 TCS MCQ Chapter Wise ...    ₹489
# 7   Book Combo for Bank Exams (Ace Quant & Ace Rea...    ₹699
# 8               Magic Book  (peparback, Rhonda Byrne)    ₹175
# 9   SSC Reasoning 7200 TCS MCQ Chapter Wise 4th Ed...    ₹499
# 10  Atulneeya Samanya Hindi For SSC GD, IBPS RRB, ...    ₹274
# 11  Bal Natik Kahaniyan - Moral Stories In Hindi (...    ₹250
# 12  SSC Maths 6800 TCS MCQ Chapter Wise I 4th Edit...    ₹489
# 13  Manogyam Magic Practice Copybook For Kids - Ha...    ₹159
# ...
